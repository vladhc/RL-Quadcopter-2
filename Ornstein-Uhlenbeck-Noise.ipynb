# %%
from agents.ou_noise import OUNoise
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exploration_mu = 0
exploration_theta = 0.05
exploration_sigma = 0.05

noise = OUNoise(1, exploration_mu, exploration_theta, exploration_sigma)

noise.reset()
y = [noise.sample() for x in range(1000)]

plt.plot(y)
